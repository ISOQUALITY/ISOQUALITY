# %% [markdown]
# <a href="https://colab.research.google.com/github/ISOQUALITY/ISOQUALITY/blob/main/limpiezadedatos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# Con este script podemos importar nuestro **dataframe** y ver las primero cinco filas.

# %%
import pandas as pd

url = 'https://raw.githubusercontent.com/ISOQUALITY/PROYECTO-SHERLOCKHR/main/Report.csv?token=AWHV2EZXQXJUSQPOHB22EILBT7YAO'
df =pd.read_csv(url)
print(df.head(5))
# Out:
#         Ofertasdetrabajo  ... Efectividaddelaoferta
# 0  Elemento de Seguridad  ...                     0
# 1  Elemento de Seguridad  ...                     0
# 2  Elemento de Seguridad  ...                     0
# 3  Elemento de Seguridad  ...                     0
# 4  Elemento de Seguridad  ...                     0
#
# [5 rows x 39 columns]

# %% [markdown]
# Con este script podemos ver todas las columnas de nuestro **DataFrame**.

# %%
import pandas as pd
url ='https://raw.githubusercontent.com/ISOQUALITY/PROYECTO-SHERLOCKHR/main/Reportfin.csv?token=AWHV2E2UDSLFZWNKXYQRLU3BUTYIG'
df=pd.read_csv(url)
df.columns
df.head()
# Out:
#               Ofertas_de_trabajo  ... Fuentes_candidatos_contratados
# 0          Elemento de Seguridad  ...                            NaN
# 1          Elemento de seguridad  ...                            NaN
# 2  Elemento de seguridad privada  ...                            NaN
# 3  Elemento de seguridad privada  ...                            NaN
# 4          Elemento de seguridad  ...                            NaN
#
# [5 rows x 42 columns]

# %% [markdown]
# Con este Script podemos relacionar dos columnas y remplazar valores  **NaN** poniendo condiciones de la columna relacional.

# %%
import pandas as pd
url ='https://raw.githubusercontent.com/ISOQUALITY/PROYECTO-SHERLOCKHR/main/Reportfin.csv?token=AWHV2E2UDSLFZWNKXYQRLU3BUTYIG'
df.columns
df.head()
df.loc[pd.isna(df["Fecha_de_contratacion"]),"Fecha_de_contratacion"]=df[pd.isna(df["Fecha_de_contratacion"])]["Estado"].apply(
    lambda x:"Indeterminado" if x=="Activa" else "Cerrada"
    
)

# %% [markdown]
# Este código nos permite ver la limpieza de la condición anterior.

# %%
df.head()
# Out:
#               Ofertas_de_trabajo  ... Fuentes_candidatos_contratados
# 0          Elemento de Seguridad  ...                            NaN
# 1          Elemento de seguridad  ...                            NaN
# 2  Elemento de seguridad privada  ...                            NaN
# 3  Elemento de seguridad privada  ...                            NaN
# 4          Elemento de seguridad  ...                            NaN
#
# [5 rows x 42 columns]

# %% [markdown]
# Este script nos permite sustituir los valores **NaN** por string que el desarrollador desea.

# %%
import pandas as pd
url ='https://raw.githubusercontent.com/ISOQUALITY/PROYECTO-SHERLOCKHR/main/Reportfin.csv?token=AWHV2E2UDSLFZWNKXYQRLU3BUTYIG'
df["Fecha_fin_publicacion"].fillna("Indeterminado",inplace =True)
df.head()
# Out:
#               Ofertas_de_trabajo  ... Fuentes_candidatos_contratados
# 0          Elemento de Seguridad  ...                            NaN
# 1          Elemento de seguridad  ...                            NaN
# 2  Elemento de seguridad privada  ...                            NaN
# 3  Elemento de seguridad privada  ...                            NaN
# 4          Elemento de seguridad  ...                            NaN
#
# [5 rows x 42 columns]

# %%
import pandas as pd
url ='https://raw.githubusercontent.com/ISOQUALITY/PROYECTO-SHERLOCKHR/main/Reportfin.csv?token=AWHV2E2UDSLFZWNKXYQRLU3BUTYIG'
df["Fecha_en_que_se_archiva_oferta"].fillna("Indeterminado",inplace =True)
df.head()
# Out:
#               Ofertas_de_trabajo  ... Fuentes_candidatos_contratados
# 0          Elemento de Seguridad  ...                            NaN
# 1          Elemento de seguridad  ...                            NaN
# 2  Elemento de seguridad privada  ...                            NaN
# 3  Elemento de seguridad privada  ...                            NaN
# 4          Elemento de seguridad  ...                            NaN
#
# [5 rows x 42 columns]

# %%
import pandas as pd
url='https://raw.githubusercontent.com/ISOQUALITY/PROYECTO-SHERLOCKHR/main/Reportfin.csv?token=AWHV2E2UDSLFZWNKXYQRLU3BUTYIG'
df["Tiempo_medio_cierre_oferta"].fillna("No aplica",inplace =True)
df.head()
# Out:
#               Ofertas_de_trabajo  ... Fuentes_candidatos_contratados
# 0          Elemento de Seguridad  ...                            NaN
# 1          Elemento de seguridad  ...                            NaN
# 2  Elemento de seguridad privada  ...                            NaN
# 3  Elemento de seguridad privada  ...                            NaN
# 4          Elemento de seguridad  ...                            NaN
#
# [5 rows x 42 columns]

# %%
import pandas as pd
url='https://raw.githubusercontent.com/ISOQUALITY/PROYECTO-SHERLOCKHR/main/Reportfin.csv?token=AWHV2E2UDSLFZWNKXYQRLU3BUTYIG'
df["Fecha_contratacion_ultimo_candidato_para_la_oferta_(01/10/2021 - 23/11/2021)"].fillna("No aplica",inplace =True)
df.head()
# Out:
#               Ofertas_de_trabajo  ... Fuentes_candidatos_contratados
# 0          Elemento de Seguridad  ...                            NaN
# 1          Elemento de seguridad  ...                            NaN
# 2  Elemento de seguridad privada  ...                            NaN
# 3  Elemento de seguridad privada  ...                            NaN
# 4          Elemento de seguridad  ...                            NaN
#
# [5 rows x 42 columns]

# %%
df["Tiempo_medio_contratacion_de_todos_los_candidatos_de_la_oferta"].fillna("No aplica", inplace =True)
df.head()
# Out:
#               Ofertas_de_trabajo  ... Fuentes_candidatos_contratados
# 0          Elemento de Seguridad  ...                            NaN
# 1          Elemento de seguridad  ...                            NaN
# 2  Elemento de seguridad privada  ...                            NaN
# 3  Elemento de seguridad privada  ...                            NaN
# 4          Elemento de seguridad  ...                            NaN
#
# [5 rows x 42 columns]

# %%
df["Fuentes_candidatos_contratados"].fillna("No aplica",inplace =True)
df.head()
# Out:
#               Ofertas_de_trabajo  ... Fuentes_candidatos_contratados
# 0          Elemento de Seguridad  ...                      No aplica
# 1          Elemento de seguridad  ...                      No aplica
# 2  Elemento de seguridad privada  ...                      No aplica
# 3  Elemento de seguridad privada  ...                      No aplica
# 4          Elemento de seguridad  ...                      No aplica
#
# [5 rows x 42 columns]

# %% [markdown]
# **Con este código podemos exportar nuestro dataframe limpio.**

# %%
df.reset_index().to_csv("datoslimpios.csv",header=True,index=False)
